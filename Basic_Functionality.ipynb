# %% [markdown]
# ## Basic Fuctionality

# %%
1+2

# %%
3-1
# Out:
# 2

# %%
4*3
# Out:
# 12

# %%
4/5
# Out:
# 0.8

# %%
9//7
# Out:
# 1

# %%
10**2
# Out:
# 100

# %%
abs(-4)
# Out:
# 4

# %%
min(2,3)
# Out:
# 2

# %%
max(4,5)
# Out:
# 5

# %%
len("helloworld")
# Out:
# 10

# %%
import math
x=math.pi
y=math.sin(x/2)
print(y)
# Out:
# 1.0

# %%
n=5
math.factorial(n)
# Out:
# 120

# %%
math.log10(2)
# Out:
# 0.3010299956639812

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %% [markdown]
# ## Functions

# %%
def square(x):
    return x*x
square(5)
# Out:
# 25

# %%
import math

def y(x):
    return math.exp(x)

print(y(5))
# Out:
# 148.4131591025766

# %%
import math

def y(x):
    return x**3

print(y(5))
# Out:
# 125

# %%
pi=3.14
def area(r):
    return pi*r*r
print(area(2))
# Out:
# 12.56
